# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
fruits = ['Apple', 'Banana', 'Orange', 'Kiwi']
fruits.extend(['Papaya', 'Grapes', 'Watermelons', 'Cherry'])

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Orange',
#  'Kiwi',
#  'Papaya',
#  'Grapes',
#  'Watermelons',
#  'Cherry']

# %%
pd.DataFrame(fruits, columns=['fruits'])
# Out:
#         fruits
# 0        Apple
# 1       Banana
# 2       Orange
# 3         Kiwi
# 4       Papaya
# 5       Grapes
# 6  Watermelons
# 7       Cherry

# %%
r = requests.get('https://www.newegg.com/p/pl?N=100006740%204814%2050001315&PageSize=60&page=1')
c=r.content
soup=BeautifulSoup(c, 'html.parser')

# %%
r.status_code
# Out:
# 200

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="show-tab-store" lang="en-us">
#  <head>
#   <title>
#    ASUS,New Laptops / Notebooks | Newegg.com
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="always" name="referrer"/>
#   <meta content="ASUS Laptops / Notebooks,New Laptops / Notebooks" name="keywords"/>
#   <meta content="Shop ASUS,New Laptops / Notebooks on Newegg.com. Watch for amazing deals and get great pricing." name="description"/>
#   <meta content="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/logo_newegg_400400.png" property="og:image"/>
#   <meta content="Shop ASUS,New Laptops / Notebooks on Newegg.com. Watch for amazing deals and get great pricing." property="og:description"/>
#   <meta content="https://www.newegg.com/p/pl?N=100006740%2050001315" property="og:url"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
soup.find_all('div',{'class':"item-cell"}, {'id':'item_cell_34-235-963_1_0'})
# Out:
# [<div class="item-cell" id="item_cell_34-235-963_1_0"><div class="item-container"><a class="item-img" href="https://www.newegg.com/indie-black-asus-vivobook-k513eq-nb74-home-personal/p/N82E16834235963?Item=N82E16834235963"><img alt="ASUS VivoBook 15 OLED K513 Laptop, 15.6 OLED Display, Intel i7-1165G7 CPU, NVIDIA GeForce MX350 GPU, 8GB RAM, 512GB PCIe SSD, Fingerprint Reader, Windows 10 Home, Indie Black, K513EQ-NB74" src="https://c1.neweggimages.com/ProductImageCompressAll300/34-235-963-V01.jpg" title="ASUS VivoBook 15 OLED K513 Laptop, 15.6 OLED Display, Intel i7-1165G7 CPU, NVIDIA GeForce MX350 GPU, 8GB RAM, 512GB PCIe SSD, Fingerprint Reader, Windows 10 Home, Indie Black, K513EQ-NB74"/><div class="btn btn-large btn-quickview">Quick View</div><div class="item-quick-action-container"><button class="quick-action"><i class="fa fa-heart-outline"></i></button></div></a><div class="item-info"><div class="item-branding"><a class="item-brand" href="https://www.newegg.com/ASUS/BrandStore/I
# ...
